# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime

# %%
df = pd.read_csv(os.path.join("dataset", "GrupoFleuryAgosto", "GrupoFleury_Exames_2.csv"), sep="|")
df.head()
# Out:
#                         ID_PACIENTE   DT_COLETA DE_ORIGEM  \
# 0  1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 1  1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 2  7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 3  7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 4  7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
#
#                                             DE_EXAME  \
# 0  NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 1  NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 2                            HEMOGRAMA, sangue total
# 3                            HEMOGRAMA, sangue total
# 4                            HEMOGRAMA, sangue total
#
#                    DE_ANALITO            DE_RESULTADO CD_UNIDADE  \
# 0  Covid 19, Detecção por PCR           NÃO DETECTADO        NaN
# 1          Covid 19, Material  raspado de nasofaringe        NaN
# 2                 Hemoglobina                    15,2       g/dL
# ...

# %%
df.DE_RESULTADO.value_counts()
# Out:
# NÃO REAGENTE                                                                                                          369595
# 0,1                                                                                                                   180863
# negativa                                                                                                              108512
# não reagente                                                                                                          101166
# 0,6                                                                                                                    80178
#                                                                                                                        ...
# microcitose moderada, poiquilocitose moderada, algumas hemácias em alvo, raros esquizócitos, policromasia discreta         1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5873403 entries, 0 to 5873402
# Data columns (total 8 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   ID_PACIENTE          object
#  1   DT_COLETA            object
#  2   DE_ORIGEM            object
#  3   DE_EXAME             object
#  4   DE_ANALITO           object
#  5   DE_RESULTADO         object
#  6   CD_UNIDADE           object
#  7   DE_VALOR_REFERENCIA  object
# dtypes: object(8)
# memory usage: 358.5+ MB

# %%
df = df[df.DE_RESULTADO.str.isnumeric()]
df.DE_RESULTADO = df.DE_RESULTADO.apply(np.float32)
df.DT_COLETA = df.DT_COLETA.apply(lambda date: datetime(int(date[6:]), int(date[3:5]), int(date[0:2])))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1819445 entries, 4 to 5873398
# Data columns (total 8 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   ID_PACIENTE          object
#  1   DT_COLETA            datetime64[ns]
#  2   DE_ORIGEM            object
#  3   DE_EXAME             object
#  4   DE_ANALITO           object
#  5   DE_RESULTADO         float64
#  6   CD_UNIDADE           object
#  7   DE_VALOR_REFERENCIA  object
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 124.9+ MB

# %%
df.groupby("ID_PACIENTE").count()
# Out:
#                                   DT_COLETA  DE_ORIGEM  DE_EXAME  DE_ANALITO  \
# ID_PACIENTE
# 00007BB4274722A63A38D415ACCD7705         74         74        74          74
# 000085C48A31F50AE4F147392F6F35CF         93         93        93          93
# 00029A8E0091126C7A0D22568D37C5AA         14         14        14          14
# 0005E27C2FE72D781FC713004443FEA3         56         56        56          56
# 0005F41F61454BBE455B910CE6CF30F6         35         35        35          35
# ...                                     ...        ...       ...         ...
# FFF9C583FA951A957A64236C005ED074         25         25        25          25
# FFFB34F871D6727F0B9CEBF5F00F8314         16         16        16          16
# FFFCBF9E5F54A15C71B56129A4E65774        100        100       100         100
# FFFD9CB0DA1DEFECCCEFBA68D04E940D         30         30        30          30
# FFFDEB16C0665899C5F4E41C117BCFEA         50         50        50          50
#
# ...
