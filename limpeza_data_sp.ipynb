# %%
import pandas as pd
import numpy as np
import os

# %%
# !wget https://raw.githubusercontent.com/seade-R/dados-covid-sp/master/data/casos_obitos_doencas_preexistentes.csv.zip
# !unzip casos_obitos_doencas_preexistentes.csv.zip -d dataset/
# !mv dataset/home/lasagna/dados-covid-sp/data/casos_obitos_doencas_preexistentes.csv dataset/
# !rm -rf dataset/home

# %%
df = pd.read_csv(os.path.join("dataset", "casos_obitos_doencas_preexistentes.csv"), sep=";", index_col=0)
df
# Out:
#             codigo_ibge  idade    cs_sexo diagnostico_covid19  \
# nome_munic
# São Paulo       3550308   32.0   FEMININO          CONFIRMADO
# São Paulo       3550308   33.0  MASCULINO          CONFIRMADO
# São Paulo       3550308   37.0   FEMININO          CONFIRMADO
# São Paulo       3550308   30.0  MASCULINO          CONFIRMADO
# São Paulo       3550308   64.0  MASCULINO          CONFIRMADO
# ...                 ...    ...        ...                 ...
# São Paulo       3550308   80.0   FEMININO          CONFIRMADO
# São Paulo       3550308   58.0  MASCULINO          CONFIRMADO
# São Paulo       3550308   30.0   FEMININO          CONFIRMADO
# São Paulo       3550308   32.0   FEMININO          CONFIRMADO
# São Paulo       3550308   67.0  MASCULINO          CONFIRMADO
#
#            data_inicio_sintomas  obito      asma cardiopatia  diabetes  \
# nome_munic
# São Paulo            05/21/2020      0  IGNORADO    IGNORADO  IGNORADO
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 991725 entries, São Paulo to São Paulo
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   codigo_ibge              991725 non-null  int64
#  1   idade                    991200 non-null  float64
#  2   cs_sexo                  991725 non-null  object
#  3   diagnostico_covid19      991725 non-null  object
#  4   data_inicio_sintomas     970236 non-null  object
#  5   obito                    991725 non-null  int64
#  6   asma                     991725 non-null  object
#  7   cardiopatia              991725 non-null  object
#  8   diabetes                 991725 non-null  object
#  9   doenca_hematologica      991725 non-null  object
#  10  doenca_hepatica          991725 non-null  object
#  11  doenca_neurologica       991725 non-null  object
#  12  doenca_renal             991725 non-null  object
# ...

# %%
df.replace("IGNORADO", np.nan, inplace=True)
df.head()
# Out:
#             codigo_ibge  idade    cs_sexo diagnostico_covid19  \
# nome_munic
# São Paulo       3550308   32.0   FEMININO          CONFIRMADO
# São Paulo       3550308   33.0  MASCULINO          CONFIRMADO
# São Paulo       3550308   37.0   FEMININO          CONFIRMADO
# São Paulo       3550308   30.0  MASCULINO          CONFIRMADO
# São Paulo       3550308   64.0  MASCULINO          CONFIRMADO
#
#            data_inicio_sintomas  obito asma cardiopatia diabetes  \
# nome_munic
# São Paulo            05/21/2020      0  NaN         NaN      NaN
# São Paulo            05/19/2020      0  NaN         NaN      NaN
# São Paulo            05/19/2020      0  NaN         NaN      NaN
# São Paulo            07/08/2020      0  NaN         NaN      NaN
# São Paulo            08/14/2020      0  NaN         NaN      NaN
#
#            doenca_hematologica doenca_hepatica doenca_neurologica  \
# nome_munic
# São Paulo                  NaN             NaN                NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 991725 entries, São Paulo to São Paulo
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   codigo_ibge              991725 non-null  int64
#  1   idade                    991200 non-null  float64
#  2   cs_sexo                  991706 non-null  object
#  3   diagnostico_covid19      991725 non-null  object
#  4   data_inicio_sintomas     970236 non-null  object
#  5   obito                    991725 non-null  int64
#  6   asma                     52564 non-null   object
#  7   cardiopatia              69488 non-null   object
#  8   diabetes                 64455 non-null   object
#  9   doenca_hematologica      51713 non-null   object
#  10  doenca_hepatica          51511 non-null   object
#  11  doenca_neurologica       53466 non-null   object
#  12  doenca_renal             52981 non-null   object
# ...

# %%
df.to_csv(os.path.join("dataset", "dataset_sp_limpo.csv"))
